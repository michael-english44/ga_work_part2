# %% [markdown]
# # Introduction to Sabermetrics
#
# To begin, let's use the `Pandas` library to determine some basic descriptive information about some given seasons, and create columns to compute the **batting average** of players.  We will use data from the Lahman database.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv('data/lahman/Batting.csv')

# %%
df.head()
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...    RBI   SB  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...    0.0  0.0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...   13.0  8.0
# 2  allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...   19.0  3.0
# 3  allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...   27.0  1.0
# 4  ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...   16.0  6.0
#
#     CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0  0.0   0  0.0  NaN  NaN NaN NaN   0.0
# 1  1.0   4  0.0  NaN  NaN NaN NaN   0.0
# 2  1.0   2  5.0  NaN  NaN NaN NaN   1.0
# 3  1.0   0  2.0  NaN  NaN NaN NaN   0.0
# 4  2.0   2  1.0  NaN  NaN NaN NaN   0.0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104324 entries, 0 to 104323
# Data columns (total 22 columns):
# playerID    104324 non-null object
# yearID      104324 non-null int64
# stint       104324 non-null int64
# teamID      104324 non-null object
# lgID        103586 non-null object
# G           104324 non-null int64
# AB          104324 non-null int64
# R           104324 non-null int64
# H           104324 non-null int64
# 2B          104324 non-null int64
# 3B          104324 non-null int64
# HR          104324 non-null int64
# RBI         103568 non-null float64
# SB          101956 non-null float64
# CS          80832 non-null float64
# BB          104324 non-null int64
# SO          97974 non-null float64
# IBB         67722 non-null float64
# HBP         101507 non-null float64
# SH          98255 non-null float64
# SF          68259 non-null float64
# GIDP        78921 non-null float64
# dtypes: float64(9), int64(10), object(3)
# memory usage: 17.5+ MB

# %% [markdown]
# According to the documentation, these are the variable descriptions:
#
# - `playerID`       Player ID code
# - `yearID`         Year
# - `stint`          player's stint (order of appearances within a season)
# - `teamID`         Team
# - `lgID`           League
# - `G`              Games
# - `AB`             At Bats
# - `R`              Runs
# - `H`              Hits
# - `2B`             Doubles
# - `3B`             Triples
# - `HR `            Homeruns
# - `RBI`            Runs Batted In
# - `SB`             Stolen Bases
# - `CS`             Caught Stealing
# - `BB`             Base on Balls
# - `SO`             Strikeouts
# - `IBB`            Intentional walks
# - `HBP`            Hit by pitch
# - `SH`             Sacrifice hits
# - `SF`             Sacrifice flies
# - `GIDP`           Grounded into double plays
#
#
# So, here are some questions:
#
# 1. Who has the most hits in a season?
# 2. Most homeruns?
# 3. What team had the most hits in 2011?
# 4. Does it seem to matter what league you're in as to the number of hits?
#
# We will find that the hitting data doesn't contain very detailed information about the players, so we will use the additional player table to then find the players first and last name.

# %%
df.nlargest(1, 'H')
# Out:
#         playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...   \
# 85828  suzukic01    2004      1    SEA   AL  161  704  101  262  24  ...
#
#         RBI    SB    CS  BB    SO   IBB  HBP   SH   SF  GIDP
# 85828  60.0  36.0  11.0  49  63.0  19.0  4.0  2.0  3.0   6.0
#
# [1 rows x 22 columns]

# %%
player = pd.read_csv('data/lahman/People.csv')

# %%
player.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay    ...     nameLast  \
# 0      Denver        NaN         NaN       NaN    ...      Aardsma
# 1      Mobile        NaN         NaN       NaN    ...        Aaron
# 2      Mobile     1984.0         8.0      16.0    ...        Aaron
# 3      Orange        NaN         NaN       NaN    ...         Aase
# 4  Palm Beach        NaN         NaN       NaN    ...         Abad
#
#         nameGiven weight height bats throws       debut   finalGame   retroID  \
# 0     David Allan  215.0   75.0    R      R  2004-04-06  2015-08-23  aardd001
# 1     Henry Louis  180.0   72.0    R      R  1954-04-13  1976-10-03  aaroh101
# 2      Tommie Lee  190.0   75.0    R      R  1962-04-10  1971-09-26  aarot101
# 3  Donald William  190.0   75.0    R      R  1977-07-26  1990-10-03  aased001
# 4   Fausto Andres  184.0   73.0    L      L  2001-09-10  2006-04-13  abada001
#
#      bbrefID
# 0  aardsda01
# 1  aaronha01
# 2  aaronto01
# 3   aasedo01
# 4   abadan01
#
# [5 rows x 24 columns]

# %%
df.nlargest(1, 'H').merge(player, on='playerID')[['yearID', 'nameGiven', 'H', 'nameLast', 'nameFirst']]
# Out:
#    yearID nameGiven    H nameLast nameFirst
# 0    2004    Ichiro  262   Suzuki    Ichiro

# %%
df.nlargest(1, 'HR').merge(player, on='playerID')[['yearID', 'nameFirst', 'nameLast', 'HR']]
# Out:
#    yearID nameFirst nameLast  HR
# 0    2001     Barry    Bonds  73

# %% [markdown]
# ## Looking For Relationships
#
# An important quantity is Runs scored.  We want to explore variables for relationships to the runs scored.  First, let's consider some regular statistics that might be familiar.
#
# ### Batting Average
#
# $$BA = \frac{\text{Hits}}{\text{At Bats}}$$

# %%
df['batting_average'] = df.H / df.AB

# %%
df.batting_average.mean()
# Out:
# 0.20862018734214524

# %%
plt.scatter(df.batting_average, df.R)

# %%
teams = df.groupby('teamID')[['batting_average', 'R']].mean()

# %%
teams.head()
# Out:
#         batting_average          R
# teamID
# ALT            0.238714   5.000000
# ANA            0.221224  18.709199
# ARI            0.198155  15.910270
# ATL            0.198994  16.662344
# BAL            0.209805  17.086807

# %%
teams.plot.scatter('R', 'batting_average', figsize = (9, 4), title = 'Runs against Batting Average')

# %%
plt.figure(figsize = (9, 4))
sns.regplot('R', 'batting_average', data = teams)
# Out:
# /Users/NYCMath/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
def lin_reg_plot(df, x, y):
    lr = LinearRegression()
    lr.fit(df[x].values.reshape(-1,1), df[y])
    pred = lr.predict(df[x].values.reshape(-1,1))
    print('Score: ', lr.score(df[x].values.reshape(-1,1), df[y]))
    plt.figure(figsize = (9, 4))
    sns.regplot(x, y, data = df)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg_plot(teams, 'R', 'batting_average')
# Out:
# Score:  0.3326779630407175
# /Users/NYCMath/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104324 entries, 0 to 104323
# Data columns (total 23 columns):
# playerID           104324 non-null object
# yearID             104324 non-null int64
# stint              104324 non-null int64
# teamID             104324 non-null object
# lgID               103586 non-null object
# G                  104324 non-null int64
# AB                 104324 non-null int64
# R                  104324 non-null int64
# H                  104324 non-null int64
# 2B                 104324 non-null int64
# 3B                 104324 non-null int64
# HR                 104324 non-null int64
# RBI                103568 non-null float64
# SB                 101956 non-null float64
# CS                 80832 non-null float64
# BB                 104324 non-null int64
# SO                 97974 non-null float64
# IBB                67722 non-null float64
# HBP                101507 non-null float64
# SH                 98255 non-null float64
# SF                 68259 non-null float64
# GIDP               78921 non-null float64
# batting_average    88461 non-null float64
# dtypes: float64(10), int64(10), object(3)
# memory usage: 18.3+ MB

# %%
run_counts = df[(df['yearID'] > 1954) & (df['yearID'] < 2012)].groupby(['yearID', 'teamID'])[['R', 'batting_average']].agg({'R': 'sum', 'batting_average': 'mean'})
ba= df[(df['yearID'] > 1954) & (df['yearID'] < 2012)].groupby(['yearID', 'teamID'])[['batting_average']].mean()

# %%
ba.shape
# Out:
# (1422, 1)

# %%
run_counts.shape
# Out:
# (1422, 2)

# %%
plt.figure(figsize = (9, 4))
sns.regplot( run_counts.R, run_counts.batting_average)

# %%
y = run_counts.batting_average
X = run_counts.R.values.reshape(-1,1)
lr = LinearRegression()
lr.fit(X, y)
lr.score(X, y)
# Out:
# 0.07777602996325228

# %%
lr.coef_
# Out:
# array([7.96023471e-05])

# %%
lr.intercept_
# Out:
# 0.15241354901746035

# %%
X.shape
# Out:
# (1422, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104324 entries, 0 to 104323
# Data columns (total 23 columns):
# playerID           104324 non-null object
# yearID             104324 non-null int64
# stint              104324 non-null int64
# teamID             104324 non-null object
# lgID               103586 non-null object
# G                  104324 non-null int64
# AB                 104324 non-null int64
# R                  104324 non-null int64
# H                  104324 non-null int64
# 2B                 104324 non-null int64
# 3B                 104324 non-null int64
# HR                 104324 non-null int64
# RBI                103568 non-null float64
# SB                 101956 non-null float64
# CS                 80832 non-null float64
# BB                 104324 non-null int64
# SO                 97974 non-null float64
# IBB                67722 non-null float64
# HBP                101507 non-null float64
# SH                 98255 non-null float64
# SF                 68259 non-null float64
# GIDP               78921 non-null float64
# batting_average    88461 non-null float64
# dtypes: float64(10), int64(10), object(3)
# memory usage: 18.3+ MB

# %%
players = df[df.AB > 40]

# %%
run_counts = players[(players['yearID'] > 1954) & (players['yearID'] < 2012)].groupby(['yearID', 'teamID'])[['R', 'batting_average']].agg({'R': 'sum', 'batting_average': 'mean'})
ba= players[(players['yearID'] > 1954) & (players['yearID'] < 2012)].groupby(['yearID', 'teamID'])[['batting_average']].mean()

# %%
plt.figure(figsize = (9, 4))
sns.regplot( run_counts.R, run_counts.batting_average)
# Out:
# /Users/NYCMath/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
y = run_counts.batting_average
X = run_counts.R.values.reshape(-1,1)
lr = LinearRegression()
lr.fit(X, y)
lr.score(X, y)
# Out:
# 0.3571644589654342

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104324 entries, 0 to 104323
# Data columns (total 23 columns):
# playerID           104324 non-null object
# yearID             104324 non-null int64
# stint              104324 non-null int64
# teamID             104324 non-null object
# lgID               103586 non-null object
# G                  104324 non-null int64
# AB                 104324 non-null int64
# R                  104324 non-null int64
# H                  104324 non-null int64
# 2B                 104324 non-null int64
# 3B                 104324 non-null int64
# HR                 104324 non-null int64
# RBI                103568 non-null float64
# SB                 101956 non-null float64
# CS                 80832 non-null float64
# BB                 104324 non-null int64
# SO                 97974 non-null float64
# IBB                67722 non-null float64
# HBP                101507 non-null float64
# SH                 98255 non-null float64
# SF                 68259 non-null float64
# GIDP               78921 non-null float64
# batting_average    88461 non-null float64
# dtypes: float64(10), int64(10), object(3)
# memory usage: 18.3+ MB

# %%
ba = df.groupby(['teamID', 'yearID'])['H'].sum()/df.groupby('teamID')['AB'].sum()
r = df.groupby(['teamID', 'yearID'])['R'].sum()

# %%
mod = df[df.yearID > 1950]

# %%
teams_years = mod.groupby(['teamID', 'yearID'])[['H', 'R', '2B', '3B', 'HR', 'SF', 'AB', 'BB', 'HBP']].sum()

# %%
team = teams_years.reset_index()

# %%
team.loc[:, 'team_ba'] = team.H/team.AB
team.loc[:, 'OBP'] = (team.H + team.BB + team.HBP)/(team.AB + team.BB + team.HBP + team.SF)
team.loc[:, 'total_bases'] = team.H + team.BB + team.HBP
team.loc[:, '1B'] = team.H - (team['2B'] + team['3B'] + team['HR'])
team.loc[:, 'slug'] = (team['1B'] + 2*team['2B'] + 3*team['3B'] + 4*team['HR'])/team.AB
team.loc[:, 'OPS'] = team.OBP + team.slug
team.loc[:, 'rc'] = ((team.H + team.BB)*team.total_bases )/(team.AB + team.BB)

# %% [markdown]
# ### PROBLEM
#
# - Runs vs. Home Runs
# - Runs vs. Home Runs Allowed
# - Runs vs. Hits
# - On Base Percentage vs. Runs
#
# $$\text{On Base Percentage} = \frac{H + BB + HBP}{AB + BB + HBP + SF}$$
#
# Note the numerator is referred to as **Total Bases**(TB)
# - Slugging Percentage vs. Runs
#
# $$\text{Slugging Percentage} = \frac{1B + 2B*2 + 3B*3 + HR*4}{AB}$$
#
# - OPS
#
# $$OPS = OBP + SLG$$
#
# - Runs Created
#
# $$\text{Runs Created} = \frac{(H + BB) * TB}{AB + BB}$$

# %%
team.head()
# Out:
#   teamID  yearID     H    R   2B  3B   HR    SF    AB   BB   HBP   team_ba  \
# 0    ANA    1997  1531  829  279  25  161  57.0  5628  617  45.0  0.272033
# 1    ANA    1998  1530  787  314  27  147  41.0  5630  510  48.0  0.271758
# 2    ANA    1999  1404  711  248  22  158  42.0  5494  511  43.0  0.255552
# 3    ANA    2000  1574  864  309  34  236  43.0  5628  608  47.0  0.279673
# 4    ANA    2001  1447  691  275  26  158  53.0  5551  494  77.0  0.260674
#
#         OBP  total_bases    1B      slug       OPS          rc
# 0  0.345518       2193.0  1066  0.416311  0.761829  754.293675
# 1  0.335206       2088.0  1042  0.415453  0.750659  693.732899
# 2  0.321511       1958.0   976  0.394976  0.716487  624.407993
# 3  0.352355       2229.0   995  0.472459  0.824814  779.935536
# 4  0.326802       2018.0   988  0.404972  0.731774  647.963275

# %%
plt.scatter(team.R, team.team_ba, alpha = 0.3)
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
def get_lin_reg_info(X, y):
    #split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    
    #instantiate and fit Regression model
    lr = LinearRegression()
    lr.fit(X_train.values.reshape(-1,1), y_train)
    
    #Get train and test predictions and print the errors
    train_pred = lr.predict(X_train.values.reshape(-1,1))
    trmse = mean_squared_error(train_pred, y_train)
    rmse = np.sqrt(mean_squared_error(lr.predict(X_test.values.reshape(-1,1)), y_test))
    print("The R2 score is: {:.5f}".format(lr.score(X_train.values.reshape(-1,1), y_train)),"\nThe train RMSE is: {:.6f}".format(trmse),"\nThe test RMSE is:{:.6f}".format(rmse))
    
    #make a scatterplot of results and data
    plt.figure(figsize = (10, 5))
    plt.scatter(X, y, label = 'data')
    plt.plot(X, lr.predict(X.values.reshape(-1,1)), label = 'Predictions', color = 'orange')
    plt.legend()

# %%
get_lin_reg_info(team.R, team.team_ba)
# Out:
# The R2 score is: 0.53784
# The train RMSE is: 0.000075
# The test RMSE is:0.009175

# %%
get_lin_reg_info(team.R, team.OBP)
# Out:
# The R2 score is: 0.62470
# The train RMSE is: 0.000083
# The test RMSE is:0.009984

# %%
get_lin_reg_info(team.R,team.slug)
# Out:
# The R2 score is: 0.68121
# The train RMSE is: 0.000338
# The test RMSE is:0.016403

# %%
get_lin_reg_info(team.R,team.OPS)
# Out:
# The R2 score is: 0.74099
# The train RMSE is: 0.000523
# The test RMSE is:0.020635

# %%
team[((team.R > 300) & (team.R < 700)) & ((team.OPS)> 0.6)]
# Out:
#      teamID  yearID     H    R   2B  3B   HR    SF    AB   BB   HBP   team_ba  \
# 4       ANA    2001  1447  691  275  26  158  53.0  5551  494  77.0  0.260674
# 8       ARI    1998  1353  665  235  46  159  27.0  5491  489  64.0  0.246403
# 14      ARI    2004  1401  615  295  38  135  37.0  5544  441  35.0  0.252706
# 15      ARI    2005  1419  696  291  27  191  45.0  5550  606  55.0  0.255676
# 23      ARI    2013  1468  685  302  31  130  43.0  5676  519  43.0  0.258633
# 24      ARI    2014  1379  615  259  47  118  36.0  5552  398  43.0  0.248379
# 29      ATL    1967  1307  631  191  29  158  36.0  5450  512  33.0  0.239817
# 30      ATL    1968  1399  514  179  31   80  30.0  5552  414  36.0  0.251981
# 31      ATL    1969  1411  691  195  22  141  34.0  5460  485  32.0  0.258425
# 33      ATL    1971  1434  643  192  30  153  44.0  5575  434  28.0  0.257220
# 34      ATL    1972  1363  628  186  17  144  38.0  5278  532  35.0  0.258242
# 36      ATL    1974  1375  661  202  37  120  42.0  5533  571  24.0  0.248509
# 37      ATL    1975  1323  583  179  28  107  35.0  5424  543  18.0  0.243916
# 38      ATL    1976  1309  620  170  30   82  47.0  5345  589  19.0  0.244902
# 39      ATL    1977  1404  678  218  20  139  34.0  5534  537  17.0  0.253704
# 40      ATL    1978  1313  600  191  39  123  47.0  5381  550  27.0  0.244007
# 41      ATL    1979  1389  669  220  28  126  38.0  5422  490  23.0  0.256179
# 42      ATL    1980  1352  630  226  22  144  33.0  5402  434  20.0  0.250278
# 43      ATL    1981   886  395  148  22   64  18.0  3642  321  18.0  0.243273
# 46      ATL    1984  1338  632  234  27  111  45.0  5422  555  20.0  0.246772
# 47      ATL    1985  1359  632  213  28  126  41.0  5526  553  22.0  0.245928
# 48      ATL    1986  1348  615  241  24  138  42.0  5384  538  24.0  0.250371
# 50      ATL    1988  1319  555  228  28   96  46.0  5440  432  21.0  0.242463
# 51      ATL    1989  1281  584  201  22  128  42.0  5463  485  24.0  0.234487
# 52      ATL    1990  1376  682  263  26  162  31.0  5504  473  27.0  0.250000
# 54      ATL    1992  1391  682  223  48  138  50.0  5480  493  26.0  0.253832
# 56      ATL    1994  1031  542  198  18  137  29.0  3861  377  22.0  0.267029
# 57      ATL    1995  1202  645  210  27  168  34.0  4814  520  40.0  0.249688
# 73      ATL    2011  1345  641  244  16  173  30.0  5528  504  28.0  0.243307
# 75      ATL    2013  1354  688  247  21  181  35.0  5441  542  55.0  0.248851
# ...     ...     ...   ...  ...  ...  ..  ...   ...   ...  ...   ...       ...
# 1611    TOR    1997  1333  654  275  41  147  52.0  5473  487  59.0  0.243559
# 1631    TOR    2017  1320  693  269   5  222  35.0  5499  542  51.0  0.240044
# 1632    WAS    2005  1367  639  311  32  117  45.0  5426  491  89.0  0.251935
# 1634    WAS    2007  1415  673  309  31  123  41.0  5520  524  53.0  0.256341
# 1635    WAS    2008  1376  641  269  26  117  36.0  5491  534  67.0  0.250592
# 1637    WAS    2010  1355  655  250  31  149  47.0  5418  503  60.0  0.250092
# 1638    WAS    2011  1319  624  257  22  154  32.0  5441  470  65.0  0.242419
# 1640    WAS    2013  1365  656  259  27  161  39.0  5436  464  40.0  0.251104
# 1641    WAS    2014  1403  686  265  27  152  41.0  5542  517  56.0  0.253158
# 1645    WS1    1951  1399  672  242  45   54   0.0  5329  560  26.0  0.262526
# 1646    WS1    1952  1282  598  225  44   50   0.0  5357  580  30.0  0.239313
# 1647    WS1    1953  1354  687  230  53   69   0.0  5149  595  31.0  0.262964
# 1648    WS1    1954  1292  632  188  69   81  42.0  5249  610  27.0  0.246142
# 1649    WS1    1955  1277  598  178  54   80  38.0  5142  537  36.0  0.248347
# 1650    WS1    1956  1302  652  198  62  112  35.0  5202  690  41.0  0.250288
# 1651    WS1    1957  1274  603  215  38  111  41.0  5231  527  46.0  0.243548
# 1652    WS1    1958  1240  553  161  38  121  38.0  5156  477  35.0  0.240497
# 1653    WS1    1959  1205  619  173  32  163  35.0  5092  517  26.0  0.236646
# 1654    WS1    1960  1283  672  205  43  147  38.0  5248  584  48.0  0.244474
# 1655    WS2    1961  1307  618  217  44  119  44.0  5366  558  21.0  0.243571
# 1656    WS2    1962  1370  599  206  38  132  36.0  5484  466  15.0  0.249818
# 1657    WS2    1963  1237  578  190  35  138  39.0  5446  497  30.0  0.227139
# 1658    WS2    1964  1246  578  199  28  125  33.0  5396  514  28.0  0.230912
# 1659    WS2    1965  1227  591  179  33  136  37.0  5374  570  34.0  0.228322
# 1660    WS2    1966  1245  557  185  40  126  33.0  5318  450  20.0  0.234111
# 1661    WS2    1967  1211  550  168  25  115  31.0  5441  472  37.0  0.222569
# 1662    WS2    1968  1208  524  160  37  124  32.0  5400  454  39.0  0.223704
# 1663    WS2    1969  1365  694  171  40  148  36.0  5447  630  32.0  0.250597
# 1664    WS2    1970  1302  626  184  28  138  38.0  5460  635  46.0  0.238462
# 1665    WS2    1971  1219  537  189  30   86  35.0  5290  575  28.0  0.230435
#
#            OBP  total_bases    1B      slug       OPS          rc
# 4     0.326802       2018.0   988  0.404972  0.731774  647.963275
# 8     0.313952       1906.0   913  0.392825  0.706776  587.098997
# 14    0.309889       1877.0   933  0.392677  0.702566  577.683208
# 15    0.332481       2080.0   910  0.421081  0.753562  684.210526
# 23    0.323197       2030.0  1005  0.391473  0.714670  651.107345
# 24    0.301874       1820.0   955  0.375720  0.677595  543.552941
# 29    0.307080       1852.0   929  0.372477  0.679557  565.043274
# 30    0.306532       1849.0  1109  0.338617  0.645149  561.890211
# 31    0.320745       1928.0  1053  0.379670  0.700416  614.884441
# 33    0.311791       1896.0  1059  0.384753  0.696544  589.403894
# 34    0.328064       1930.0  1016  0.381773  0.709837  629.492255
# 36    0.319287       1970.0  1016  0.363456  0.682743  628.050459
# 37    0.312957       1884.0  1009  0.346423  0.659380  589.164404
# 38    0.319500       1917.0  1027  0.333957  0.653457  613.155713
# 39    0.319830       1958.0  1027  0.375678  0.695508  626.005271
# 40    0.314738       1890.0   960  0.362572  0.677310  593.672231
# 41    0.318433       1902.0  1015  0.376798  0.695231  604.509134
# 42    0.306673       1806.0   960  0.380230  0.686903  552.692940
# 43    0.306327       1225.0   652  0.348710  0.655036  373.094878
# 46    0.316617       1913.0   966  0.361306  0.677923  605.874017
# 47    0.314881       1934.0   992  0.363011  0.677892  608.292153
# 48    0.318971       1910.0   945  0.380944  0.699915  608.284363
# 50    0.298367       1772.0   967  0.347610  0.645977  528.401226
# 51    0.297639       1790.0   930  0.349625  0.647264  531.462677
# 52    0.310853       1876.0   925  0.395531  0.706384  580.345324
# 54    0.315755       1910.0   982  0.387591  0.703346  602.451030
# 56    0.333411       1430.0   678  0.434084  0.767495  475.092025
# 57    0.325814       1762.0   797  0.409223  0.735037  568.834646
# 73    0.308210       1877.0   912  0.387120  0.695330  575.360245
# 75    0.321258       1951.0   905  0.401764  0.723022  618.267759
# ...        ...          ...   ...       ...       ...         ...
# 1611  0.309504       1879.0   870  0.389366  0.698870  573.788591
# 1631  0.312225       1913.0   824  0.411893  0.724118  589.638470
# 1632  0.321765       1947.0   907  0.385735  0.707500  611.378401
# 1634  0.324536       1992.0   952  0.390399  0.714934  639.061549
# 1635  0.322617       1977.0   964  0.372974  0.695591  626.733610
# 1637  0.318182       1918.0   925  0.390181  0.708363  601.865225
# 1638  0.308589       1854.0   886  0.382650  0.691239  561.124344
# 1640  0.312594       1869.0   918  0.397535  0.710129  579.390000
# 1641  0.320988       1976.0   959  0.392999  0.713987  626.162733
# 1645  0.335587       1985.0  1058  0.355226  0.690814  660.318390
# 1646  0.317077       1892.0   963  0.325742  0.642819  593.381169
# 1647  0.342857       1980.0  1002  0.368421  0.711278  671.834958
# 1648  0.325405       1929.0   954  0.354544  0.679949  626.208909
# 1649  0.321571       1850.0   965  0.350642  0.672213  590.931502
# 1650  0.340650       2033.0   930  0.376778  0.717428  687.327902
# 1651  0.315997       1847.0   910  0.362837  0.678834  577.708753
# 1652  0.307045       1752.0   920  0.356866  0.663911  534.028759
# 1653  0.308289       1748.0   837  0.379222  0.687512  536.647531
# 1654  0.323589       1915.0   888  0.383956  0.707545  613.049554
# 1655  0.314911       1886.0   927  0.366940  0.681851  593.752532
# 1656  0.308449       1851.0   994  0.373450  0.681899  571.165714
# 1657  0.293413       1764.0   874  0.350900  0.644313  514.685512
# 1658  0.299447       1788.0   894  0.347665  0.647112  532.467005
# 1659  0.304406       1831.0   879  0.349833  0.654238  553.550976
# 1660  0.294623       1715.0   894  0.355021  0.649644  503.974515
# 1661  0.287577       1720.0   903  0.326043  0.613620  489.558600
# 1662  0.287089       1701.0   887  0.335926  0.623015  482.928254
# 1663  0.329862       2027.0  1006  0.378190  0.708052  665.437716
# 1664  0.320926       1983.0   952  0.358242  0.679167  630.200328
# 1665  0.307355       1822.0   914  0.326276  0.633631  557.317647
#
# [819 rows x 18 columns]

# %%
get_lin_reg_info(team.R, team.rc)
# Out:
# The R2 score is: 0.82877
# The train RMSE is: 1036.507417
# The test RMSE is:32.449820

# %%
team[team.R>400]
# Out:
#      teamID  yearID     H    R   2B  3B   HR    SF    AB   BB   HBP   team_ba  \
# 0       ANA    1997  1531  829  279  25  161  57.0  5628  617  45.0  0.272033
# 1       ANA    1998  1530  787  314  27  147  41.0  5630  510  48.0  0.271758
# 2       ANA    1999  1404  711  248  22  158  42.0  5494  511  43.0  0.255552
# 3       ANA    2000  1574  864  309  34  236  43.0  5628  608  47.0  0.279673
# 4       ANA    2001  1447  691  275  26  158  53.0  5551  494  77.0  0.260674
# 5       ANA    2002  1603  851  333  32  152  64.0  5678  462  74.0  0.282318
# 6       ANA    2003  1473  736  276  33  150  50.0  5487  476  56.0  0.268453
# 7       ANA    2004  1603  836  272  37  162  41.0  5675  450  73.0  0.282467
# 8       ARI    1998  1353  665  235  46  159  27.0  5491  489  64.0  0.246403
# 9       ARI    1999  1566  908  289  46  216  60.0  5658  588  48.0  0.276776
# 10      ARI    2000  1466  792  282  44  179  58.0  5527  535  59.0  0.265243
# 11      ARI    2001  1494  818  284  35  208  36.0  5595  587  57.0  0.267024
# 12      ARI    2002  1471  819  283  41  165  53.0  5508  643  50.0  0.267066
# 13      ARI    2003  1467  717  303  47  152  52.0  5570  531  45.0  0.263375
# 14      ARI    2004  1401  615  295  38  135  37.0  5544  441  35.0  0.252706
# 15      ARI    2005  1419  696  291  27  191  45.0  5550  606  55.0  0.255676
# 16      ARI    2006  1506  773  331  38  160  53.0  5645  504  67.0  0.266785
# 17      ARI    2007  1350  712  286  40  171  58.0  5398  532  57.0  0.250093
# 18      ARI    2008  1355  720  318  47  159  43.0  5409  587  49.0  0.250508
# 19      ARI    2009  1408  720  307  45  173  41.0  5565  571  37.0  0.253010
# 20      ARI    2010  1366  713  301  34  180  41.0  5473  589  39.0  0.249589
# 21      ARI    2011  1357  731  293  37  172  33.0  5421  531  61.0  0.250323
# 22      ARI    2012  1416  734  307  33  165  45.0  5462  539  41.0  0.259246
# 23      ARI    2013  1468  685  302  31  130  43.0  5676  519  43.0  0.258633
# 24      ARI    2014  1379  615  259  47  118  36.0  5552  398  43.0  0.248379
# 25      ARI    2015  1494  720  289  48  154  57.0  5649  490  33.0  0.264472
# 26      ARI    2016  1479  752  285  56  190  38.0  5665  463  50.0  0.261077
# 27      ARI    2017  1405  812  314  39  220  27.0  5525  578  54.0  0.254299
# 28      ATL    1966  1476  782  220  32  207  45.0  5617  512  40.0  0.262774
# 29      ATL    1967  1307  631  191  29  158  36.0  5450  512  33.0  0.239817
# ...     ...     ...   ...  ...  ...  ..  ...   ...   ...  ...   ...       ...
# 1636    WAS    2009  1416  710  271  38  156  42.0  5493  617  56.0  0.257783
# 1637    WAS    2010  1355  655  250  31  149  47.0  5418  503  60.0  0.250092
# 1638    WAS    2011  1319  624  257  22  154  32.0  5441  470  65.0  0.242419
# 1639    WAS    2012  1468  731  301  25  194  36.0  5615  479  41.0  0.261443
# 1640    WAS    2013  1365  656  259  27  161  39.0  5436  464  40.0  0.251104
# 1641    WAS    2014  1403  686  265  27  152  41.0  5542  517  56.0  0.253158
# 1642    WAS    2015  1363  703  265  13  177  51.0  5428  539  44.0  0.251105
# 1643    WAS    2016  1403  763  268  29  203  63.0  5490  536  64.0  0.255556
# 1644    WAS    2017  1477  819  311  31  215  45.0  5553  542  31.0  0.265982
# 1645    WS1    1951  1399  672  242  45   54   0.0  5329  560  26.0  0.262526
# 1646    WS1    1952  1282  598  225  44   50   0.0  5357  580  30.0  0.239313
# 1647    WS1    1953  1354  687  230  53   69   0.0  5149  595  31.0  0.262964
# 1648    WS1    1954  1292  632  188  69   81  42.0  5249  610  27.0  0.246142
# 1649    WS1    1955  1277  598  178  54   80  38.0  5142  537  36.0  0.248347
# 1650    WS1    1956  1302  652  198  62  112  35.0  5202  690  41.0  0.250288
# 1651    WS1    1957  1274  603  215  38  111  41.0  5231  527  46.0  0.243548
# 1652    WS1    1958  1240  553  161  38  121  38.0  5156  477  35.0  0.240497
# 1653    WS1    1959  1205  619  173  32  163  35.0  5092  517  26.0  0.236646
# 1654    WS1    1960  1283  672  205  43  147  38.0  5248  584  48.0  0.244474
# 1655    WS2    1961  1307  618  217  44  119  44.0  5366  558  21.0  0.243571
# 1656    WS2    1962  1370  599  206  38  132  36.0  5484  466  15.0  0.249818
# 1657    WS2    1963  1237  578  190  35  138  39.0  5446  497  30.0  0.227139
# 1658    WS2    1964  1246  578  199  28  125  33.0  5396  514  28.0  0.230912
# 1659    WS2    1965  1227  591  179  33  136  37.0  5374  570  34.0  0.228322
# 1660    WS2    1966  1245  557  185  40  126  33.0  5318  450  20.0  0.234111
# 1661    WS2    1967  1211  550  168  25  115  31.0  5441  472  37.0  0.222569
# 1662    WS2    1968  1208  524  160  37  124  32.0  5400  454  39.0  0.223704
# 1663    WS2    1969  1365  694  171  40  148  36.0  5447  630  32.0  0.250597
# 1664    WS2    1970  1302  626  184  28  138  38.0  5460  635  46.0  0.238462
# 1665    WS2    1971  1219  537  189  30   86  35.0  5290  575  28.0  0.230435
#
#            OBP  total_bases    1B      slug       OPS          rc
# 0     0.345518       2193.0  1066  0.416311  0.761829  754.293675
# 1     0.335206       2088.0  1042  0.415453  0.750659  693.732899
# 2     0.321511       1958.0   976  0.394976  0.716487  624.407993
# 3     0.352355       2229.0   995  0.472459  0.824814  779.935536
# 4     0.326802       2018.0   988  0.404972  0.731774  647.963275
# 5     0.340714       2139.0  1086  0.432547  0.773260  719.386808
# 6     0.330367       2005.0  1014  0.412794  0.743161  655.332048
# 7     0.340760       2126.0  1132  0.429075  0.769835  712.600490
# 8     0.313952       1906.0   913  0.392825  0.706776  587.098997
# 9     0.346553       2202.0  1015  0.458643  0.805196  759.383285
# 10    0.333387       2060.0   961  0.429347  0.762734  679.983504
# 11    0.340717       2138.0   967  0.441823  0.782540  719.698803
# 12    0.346019       2164.0   982  0.423203  0.769221  743.732076
# 13    0.329622       2043.0   965  0.416517  0.746140  669.056548
# 14    0.309889       1877.0   933  0.392677  0.702566  577.683208
# 15    0.332481       2080.0   910  0.421081  0.753562  684.210526
# 16    0.331313       2077.0   977  0.423915  0.755228  678.934786
# 17    0.320761       1939.0   853  0.412931  0.733692  615.379089
# 18    0.327037       1991.0   831  0.414864  0.741901  644.850233
# 19    0.324429       2016.0   883  0.417610  0.742039  650.205997
# 20    0.324650       1994.0   851  0.415677  0.740327  643.066645
# 21    0.322362       1949.0   855  0.413208  0.735570  618.231183
# 22    0.327912       1996.0   911  0.418162  0.746074  650.254958
# 23    0.323197       2030.0  1005  0.391473  0.714670  651.107345
# 24    0.301874       1820.0   955  0.375720  0.677595  543.552941
# 25    0.323808       2017.0  1003  0.414410  0.738218  651.853396
# 26    0.320463       1992.0   948  0.431774  0.752237  631.276762
# 27    0.329398       2037.0   832  0.444706  0.774104  661.866459
# 28    0.326360       2028.0  1017  0.423892  0.750252  657.801273
# 29    0.307080       1852.0   929  0.372477  0.679557  565.043274
# ...        ...          ...   ...       ...       ...         ...
# 1636  0.336501       2089.0   951  0.406153  0.742655  695.079705
# 1637  0.318182       1918.0   925  0.390181  0.708363  601.865225
# 1638  0.308589       1854.0   886  0.382650  0.691239  561.124344
# 1639  0.322152       1988.0   948  0.427605  0.749757  635.155235
# 1640  0.312594       1869.0   918  0.397535  0.710129  579.390000
# 1641  0.320988       1976.0   959  0.392999  0.713987  626.162733
# 1642  0.321016       1946.0   908  0.402542  0.723559  620.293615
# 1643  0.325532       2003.0   903  0.425865  0.751397  644.509957
# 1644  0.332199       2050.0   920  0.449307  0.781506  679.073011
# 1645  0.335587       1985.0  1058  0.355226  0.690814  660.318390
# 1646  0.317077       1892.0   963  0.325742  0.642819  593.381169
# 1647  0.342857       1980.0  1002  0.368421  0.711278  671.834958
# 1648  0.325405       1929.0   954  0.354544  0.679949  626.208909
# 1649  0.321571       1850.0   965  0.350642  0.672213  590.931502
# 1650  0.340650       2033.0   930  0.376778  0.717428  687.327902
# 1651  0.315997       1847.0   910  0.362837  0.678834  577.708753
# 1652  0.307045       1752.0   920  0.356866  0.663911  534.028759
# 1653  0.308289       1748.0   837  0.379222  0.687512  536.647531
# 1654  0.323589       1915.0   888  0.383956  0.707545  613.049554
# 1655  0.314911       1886.0   927  0.366940  0.681851  593.752532
# 1656  0.308449       1851.0   994  0.373450  0.681899  571.165714
# 1657  0.293413       1764.0   874  0.350900  0.644313  514.685512
# 1658  0.299447       1788.0   894  0.347665  0.647112  532.467005
# 1659  0.304406       1831.0   879  0.349833  0.654238  553.550976
# 1660  0.294623       1715.0   894  0.355021  0.649644  503.974515
# 1661  0.287577       1720.0   903  0.326043  0.613620  489.558600
# 1662  0.287089       1701.0   887  0.335926  0.623015  482.928254
# 1663  0.329862       2027.0  1006  0.378190  0.708052  665.437716
# 1664  0.320926       1983.0   952  0.358242  0.679167  630.200328
# 1665  0.307355       1822.0   914  0.326276  0.633631  557.317647
#
# [1658 rows x 18 columns]
